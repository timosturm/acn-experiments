# %%
import wandb

# This is importent when we want to call this as a python script, because jupyter naturally has a higher recursion depth
from icecream import ic
import os
import sys
sys.setrecursionlimit(3000)

# Print the PID when using nohup
ic(os.getpid())
# Out:
# ic| os.getpid(): 4083743
# 4083743

# %%
from datetime import datetime
import pickle
from typing import Optional
from gymportal.data.ev_generators import SklearnGenerator, get_data, extract_training_data
from gymportal.auxilliaries.file_utils import get_persistent_folder
import pytz
from sklearn.mixture import BayesianGaussianMixture
import numpy as np


class ScalableSklearnGenerator(SklearnGenerator):

    def __init__(
        self,
        period,
        battery_generator,
        model,
        scaler,
        frequencies_per_hour,
        duration_multiplicator=1,
        arrival_min=0,
        arrival_max=24,
        duration_min=0.0833,
        duration_max=48,
        energy_min=0.5,
        energy_max=150,
        seed=None
    ):
        super().__init__(
            period,
            battery_generator,
            model,
            frequencies_per_hour,
            duration_multiplicator,
            arrival_min, arrival_max,
            duration_min, duration_max,
            energy_min,
            energy_max,
            seed
        )

        self.scaler = scaler

    def _sample(self, n_samples: int):
        """ Generate random samples from the fitted model.

        Args:
            n_samples (int): Number of samples to generate.

        Returns:
            np.ndarray: shape (n_samples, 3), randomly generated samples. Column 1 is
                the arrival time in hours since midnight, column 2 is the session duration in hours,
                and column 3 is the energy demand in kWh.
        """
        if n_samples > 0:
            ev_matrix, _ = self.sklearn_model.sample(n_samples)
            ev_matrix = self.scaler.inverse_transform(ev_matrix)
            return self._clip_samples(ev_matrix)
        else:
            return np.array([])


def get_generator(site, model_path: str, battery_generator, token: Optional[str] = None, seed: Optional[int] = None,
                           frequency_multiplicator=10, duration_multiplicator=1):
    """

    Args:
        site: The site which is used as a data source for the generative model.
        battery_generator: The generator for EV batteries.
        token: The token to access acn-data.
        seed: A seed for random number generator
        frequency_multiplicator: A multiplicator for the arrival frequencies of EVs, e.g., a higher value makes it
            more likely for an EV to arrive at a given point in time.

    Returns:

    """
    timezone = pytz.timezone('America/Los_Angeles')
    data = get_data(
        site,
        token,
        drop_columns=(),
        start=datetime(2018, 3, 25, tzinfo=timezone),
        end=datetime(2020, 5, 31, tzinfo=timezone)
    )
    X = extract_training_data(data)

    try:
        with open(model_path, "rb") as f:
            gmm, scaler = pickle.load(f)
    except FileNotFoundError:
        print(f"No existing GMM found for site={site}!")

    connection_time = X[:, 0]

    frequencies, _ = np.histogram(connection_time, bins=range(0, 25, 1))
    frequencies = np.array(frequencies) / np.sum(frequencies)

    generator = ScalableSklearnGenerator(
        period=1,
        model=gmm,
        scaler=scaler,
        frequencies_per_hour=frequencies * frequency_multiplicator,
        battery_generator=battery_generator,
        duration_multiplicator=duration_multiplicator,
        seed=seed
    )

    return generator
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742384481.164589 4083743 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742384481.167263 4083743 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# from gymportal.data.ev_generators import get_standard_generator, RealWorldGenerator
from acnportal.acnsim import Linear2StageBattery
from gymportal.data.battery_generators import CustomizableBatteryGenerator
from gymportal.sim import get_charging_network, Recomputer, EvaluationSimulator, SimGenerator
from datetime import datetime, timedelta

import pytz
timezone = pytz.timezone("America/Los_Angeles")


# charging_network = get_charging_network('simple_acn', basic_evse=True, voltage=208,
#                                         network_kwargs={
#                                             'station_ids': ['CA-504', 'CA-503', 'CA-502', 'CA-501'],
#                                             # 'station_ids': ['CA-501'],
#                                             "aggregate_cap": 32 * 208 / 1000})

charging_network = get_charging_network('caltech', basic_evse=True, voltage=208,
                                        network_kwargs={"transformer_cap": 150})

battery_generator = CustomizableBatteryGenerator(
    voltage=208,
    period=1,
    battery_types=[
        Linear2StageBattery],
    max_power_function="normal",
)

# ev_generator = RealWorldGenerator(battery_generator=battery_generator, site='caltech', period=1)
ev_generator = get_generator(
    'caltech',
    "triple_gmm+sc.pkl",
    battery_generator,
    seed=42,
    frequency_multiplicator=10,
    duration_multiplicator=2
)


# TODO Use time intervals and GMMs from https://github.com/chrisyeh96/sustaingym/blob/main/sustaingym/envs/evcharging/utils.py
# I.e., train on generated data, evaluate on new generated data and real data from the same interval
# optional: compare to "out-of-distribution" data from different interval

train_generator = SimGenerator(
    charging_network=charging_network,
    simulation_days=1,
    n_intervals=46 * 7,
    start_date=timezone.localize(datetime(2019, 1, 1)),
    ev_generator=ev_generator,
    recomputer=Recomputer(recompute_interval=10, sparse=True),
    sim_class=EvaluationSimulator,
)

ic(train_generator.end_date + timedelta(days=1))

eval_generator = SimGenerator(
    charging_network=charging_network,
    simulation_days=7 * 4,
    n_intervals=1,
    start_date=train_generator.end_date + timedelta(days=1),
    ev_generator=ev_generator,
    recomputer=Recomputer(recompute_interval=10, sparse=True),
    sim_class=EvaluationSimulator,
)

ic(eval_generator.end_date + timedelta(days=1))

# validation_generator = SimGenerator(
#     charging_network=charging_network,
#     simulation_days=14,
#     n_intervals=1,
#     start_date=eval_generator.end_date + timedelta(days=1),
#     ev_generator=ev_generator,
#     recomputer=Recomputer(recompute_interval=10, sparse=True),
#     sim_class=EvaluationSimulator,
# )

# ic(validation_generator.end_date + timedelta(days=1))
pass
# Out:
# ic| train_generator.end_date + timedelta(days=1): datetime.datetime(2019, 11, 20, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| eval_generator.end_date + timedelta(days=1): datetime.datetime(2019, 12, 19, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)

# %%
from src.pv.pv import read_pv_data

df_pv = read_pv_data("../pv_150kW.csv")
df_pv.describe()
# Out:
#                    P           G(i)          H_sun            T2m  \
# count  140256.000000  140256.000000  140256.000000  140256.000000
# mean    30395.798319     267.983145      16.748906      17.931872
# std     40648.543625     356.157287      22.166668       7.394042
# min         0.000000       0.000000      -5.880000      -2.230000
# 25%         0.000000       0.000000       0.000000      12.360000
# 50%        87.000000       7.260000       0.520000      17.310000
# 75%     65764.500000     564.280000      31.982500      23.010000
# max    132601.500000    1143.220000      78.090000      46.460000
#
#                WS10m       Int
# count  140256.000000  140256.0
# mean        1.654366       0.0
# std         0.867817       0.0
# min         0.000000       0.0
# 25%         0.970000       0.0
# 50%         1.590000       0.0
# 75%         2.280000       0.0
# max         7.930000       0.0

# %%
from gymportal.environment import *
from src.observations import minute_observation_stay
from src.pv.observations import pv_observation_mean
from src.pv.rewards import *
from src.pv.metrics import *
from gymportal.evaluation import *


observation_objects = [
    charging_rates_observation_normalized(),
    percentage_of_magnitude_observation(),
    diff_pilots_charging_rates_observation_normalized(),
    cyclical_minute_observation(),
    cyclical_day_observation(),
    cyclical_month_observation(),
    minute_observation_stay(),
    energy_delivered_observation_normalized(),
    num_active_stations_observation_normalized(),
    pilot_signals_observation_normalized(),
    pv_observation_mean(df_pv),
]

reward_objects = [
    pv_utilization_reward(df_pv),
    # grid_use_penalty(df_pv),
    unused_pv_penalty(df_pv),
    charging_reward(),
    # soft_charging_reward_pv_weighted(df_pv, transformer_cap=150),
]

metrics = {
    "SoC >= 90%": percentage_soc,
    "mean SoC": mean_soc,
    "median SoC": median_soc,
    "prop feasible steps": proportion_of_feasible_charging,
    "prop feasible charge": proportion_of_feasible_charge,
    "pv utilization": lambda sim: pv_utilization_metric(sim, df_pv),
    "grid usage": lambda sim: grid_use_metric(sim, df_pv),
    "unused pv": lambda sim: unused_pv_metric(sim, df_pv),
}

# %%
# import dill as pickle

# with open("../caltech_#stations=54_#days=7_#intervals=46_seed=8734956.pkl", "rb") as file:
#     train_generator = pickle.load(file)

# %%
train_generator.seed = 8734956 
_ = train_generator.reset()

iter = 0

while train_generator._current_date != train_generator.start_date:
    _ = train_generator.next()

    ic(iter)
    ic(train_generator._current_date)
    iter += 1
# Out:
# ic| iter: 0
# ic| train_generator._current_date: datetime.datetime(2019, 1, 3, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 1
# ic| train_generator._current_date: datetime.datetime(2019, 1, 4, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 2
# ic| train_generator._current_date: datetime.datetime(2019, 1, 5, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 3
# ic| train_generator._current_date: datetime.datetime(2019, 1, 6, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 4
# ic| train_generator._current_date: datetime.datetime(2019, 1, 7, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 5
# ic| train_generator._current_date: datetime.datetime(2019, 1, 8, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 6
# ic| train_generator._current_date: datetime.datetime(2019, 1, 9, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 7
# ic| train_generator._current_date: datetime.datetime(2019, 1, 10, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 8
# ic| train_generator._current_date: datetime.datetime(2019, 1, 11, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 9
# ic| train_generator._current_date: datetime.datetime(2019, 1, 12, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 10
# ic| train_generator._current_date: datetime.datetime(2019, 1, 13, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 11
# ic| train_generator._current_date: datetime.datetime(2019, 1, 14, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 12
# ic| train_generator._current_date: datetime.datetime(2019, 1, 15, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 13
# ic| train_generator._current_date: datetime.datetime(2019, 1, 16, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 14
# ic| train_generator._current_date: datetime.datetime(2019, 1, 17, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 15
# ic| train_generator._current_date: datetime.datetime(2019, 1, 18, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 16
# ic| train_generator._current_date: datetime.datetime(2019, 1, 19, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 17
# ic| train_generator._current_date: datetime.datetime(2019, 1, 20, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 18
# ic| train_generator._current_date: datetime.datetime(2019, 1, 21, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 19
# ic| train_generator._current_date: datetime.datetime(2019, 1, 22, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 20
# ic| train_generator._current_date: datetime.datetime(2019, 1, 23, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 21
# ic| train_generator._current_date: datetime.datetime(2019, 1, 24, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 22
# ic| train_generator._current_date: datetime.datetime(2019, 1, 25, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 23
# ic| train_generator._current_date: datetime.datetime(2019, 1, 26, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 24
# ic| train_generator._current_date: datetime.datetime(2019, 1, 27, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 25
# ic| train_generator._current_date: datetime.datetime(2019, 1, 28, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 26
# ic| train_generator._current_date: datetime.datetime(2019, 1, 29, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 27
# ic| train_generator._current_date: datetime.datetime(2019, 1, 30, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 28
# ic| train_generator._current_date: datetime.datetime(2019, 1, 31, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 29
# ic| train_generator._current_date: datetime.datetime(2019, 2, 1, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 30
# ic| train_generator._current_date: datetime.datetime(2019, 2, 2, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 31
# ic| train_generator._current_date: datetime.datetime(2019, 2, 3, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 32
# ic| train_generator._current_date: datetime.datetime(2019, 2, 4, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 33
# ic| train_generator._current_date: datetime.datetime(2019, 2, 5, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 34
# ic| train_generator._current_date: datetime.datetime(2019, 2, 6, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 35
# ic| train_generator._current_date: datetime.datetime(2019, 2, 7, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 36
# ic| train_generator._current_date: datetime.datetime(2019, 2, 8, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 37
# ic| train_generator._current_date: datetime.datetime(2019, 2, 9, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 38
# ic| train_generator._current_date: datetime.datetime(2019, 2, 10, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 39
# ic| train_generator._current_date: datetime.datetime(2019, 2, 11, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 40
# ic| train_generator._current_date: datetime.datetime(2019, 2, 12, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 41
# ic| train_generator._current_date: datetime.datetime(2019, 2, 13, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 42
# ic| train_generator._current_date: datetime.datetime(2019, 2, 14, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 43
# ic| train_generator._current_date: datetime.datetime(2019, 2, 15, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 44
# ic| train_generator._current_date: datetime.datetime(2019, 2, 16, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 45
# ic| train_generator._current_date: datetime.datetime(2019, 2, 17, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 46
# ic| train_generator._current_date: datetime.datetime(2019, 2, 18, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 47
# ic| train_generator._current_date: datetime.datetime(2019, 2, 19, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 48
# ic| train_generator._current_date: datetime.datetime(2019, 2, 20, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 49
# ic| train_generator._current_date: datetime.datetime(2019, 2, 21, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 50
# ic| train_generator._current_date: datetime.datetime(2019, 2, 22, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 51
# ic| train_generator._current_date: datetime.datetime(2019, 2, 23, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 52
# ic| train_generator._current_date: datetime.datetime(2019, 2, 24, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 53
# ic| train_generator._current_date: datetime.datetime(2019, 2, 25, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 54
# ic| train_generator._current_date: datetime.datetime(2019, 2, 26, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 55
# ic| train_generator._current_date: datetime.datetime(2019, 2, 27, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 56
# ic| train_generator._current_date: datetime.datetime(2019, 2, 28, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 57
# ic| train_generator._current_date: datetime.datetime(2019, 3, 1, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 58
# ic| train_generator._current_date: datetime.datetime(2019, 3, 2, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 59
# ic| train_generator._current_date: datetime.datetime(2019, 3, 3, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 60
# ic| train_generator._current_date: datetime.datetime(2019, 3, 4, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 61
# ic| train_generator._current_date: datetime.datetime(2019, 3, 5, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 62
# ic| train_generator._current_date: datetime.datetime(2019, 3, 6, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 63
# ic| train_generator._current_date: datetime.datetime(2019, 3, 7, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 64
# ic| train_generator._current_date: datetime.datetime(2019, 3, 8, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 65
# ic| train_generator._current_date: datetime.datetime(2019, 3, 9, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 66
# ic| train_generator._current_date: datetime.datetime(2019, 3, 10, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 67
# ic| train_generator._current_date: datetime.datetime(2019, 3, 11, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 68
# ic| train_generator._current_date: datetime.datetime(2019, 3, 12, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 69
# ic| train_generator._current_date: datetime.datetime(2019, 3, 13, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 70
# ic| train_generator._current_date: datetime.datetime(2019, 3, 14, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 71
# ic| train_generator._current_date: datetime.datetime(2019, 3, 15, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 72
# ic| train_generator._current_date: datetime.datetime(2019, 3, 16, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 73
# ic| train_generator._current_date: datetime.datetime(2019, 3, 17, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 74
# ic| train_generator._current_date: datetime.datetime(2019, 3, 18, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 75
# ic| train_generator._current_date: datetime.datetime(2019, 3, 19, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 76
# ic| train_generator._current_date: datetime.datetime(2019, 3, 20, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 77
# ic| train_generator._current_date: datetime.datetime(2019, 3, 21, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 78
# ic| train_generator._current_date: datetime.datetime(2019, 3, 22, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 79
# ic| train_generator._current_date: datetime.datetime(2019, 3, 23, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 80
# ic| train_generator._current_date: datetime.datetime(2019, 3, 24, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 81
# ic| train_generator._current_date: datetime.datetime(2019, 3, 25, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 82
# ic| train_generator._current_date: datetime.datetime(2019, 3, 26, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 83
# ic| train_generator._current_date: datetime.datetime(2019, 3, 27, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 84
# ic| train_generator._current_date: datetime.datetime(2019, 3, 28, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 85
# ic| train_generator._current_date: datetime.datetime(2019, 3, 29, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 86
# ic| train_generator._current_date: datetime.datetime(2019, 3, 30, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 87
# ic| train_generator._current_date: datetime.datetime(2019, 3, 31, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 88
# ic| train_generator._current_date: datetime.datetime(2019, 4, 1, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 89
# ic| train_generator._current_date: datetime.datetime(2019, 4, 2, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 90
# ic| train_generator._current_date: datetime.datetime(2019, 4, 3, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 91
# ic| train_generator._current_date: datetime.datetime(2019, 4, 4, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 92
# ic| train_generator._current_date: datetime.datetime(2019, 4, 5, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 93
# ic| train_generator._current_date: datetime.datetime(2019, 4, 6, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 94
# ic| train_generator._current_date: datetime.datetime(2019, 4, 7, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 95
# ic| train_generator._current_date: datetime.datetime(2019, 4, 8, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 96
# ic| train_generator._current_date: datetime.datetime(2019, 4, 9, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 97
# ic| train_generator._current_date: datetime.datetime(2019, 4, 10, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 98
# ic| train_generator._current_date: datetime.datetime(2019, 4, 11, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 99
# ic| train_generator._current_date: datetime.datetime(2019, 4, 12, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 100
# ic| train_generator._current_date: datetime.datetime(2019, 4, 13, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 101
# ic| train_generator._current_date: datetime.datetime(2019, 4, 14, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 102
# ic| train_generator._current_date: datetime.datetime(2019, 4, 15, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 103
# ic| train_generator._current_date: datetime.datetime(2019, 4, 16, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 104
# ic| train_generator._current_date: datetime.datetime(2019, 4, 17, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 105
# ic| train_generator._current_date: datetime.datetime(2019, 4, 18, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 106
# ic| train_generator._current_date: datetime.datetime(2019, 4, 19, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 107
# ic| train_generator._current_date: datetime.datetime(2019, 4, 20, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 108
# ic| train_generator._current_date: datetime.datetime(2019, 4, 21, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 109
# ic| train_generator._current_date: datetime.datetime(2019, 4, 22, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 110
# ic| train_generator._current_date: datetime.datetime(2019, 4, 23, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 111
# ic| train_generator._current_date: datetime.datetime(2019, 4, 24, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 112
# ic| train_generator._current_date: datetime.datetime(2019, 4, 25, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 113
# ic| train_generator._current_date: datetime.datetime(2019, 4, 26, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 114
# ic| train_generator._current_date: datetime.datetime(2019, 4, 27, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 115
# ic| train_generator._current_date: datetime.datetime(2019, 4, 28, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 116
# ic| train_generator._current_date: datetime.datetime(2019, 4, 29, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 117
# ic| train_generator._current_date: datetime.datetime(2019, 4, 30, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 118
# ic| train_generator._current_date: datetime.datetime(2019, 5, 1, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 119
# ic| train_generator._current_date: datetime.datetime(2019, 5, 2, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 120
# ic| train_generator._current_date: datetime.datetime(2019, 5, 3, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 121
# ic| train_generator._current_date: datetime.datetime(2019, 5, 4, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 122
# ic| train_generator._current_date: datetime.datetime(2019, 5, 5, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 123
# ic| train_generator._current_date: datetime.datetime(2019, 5, 6, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 124
# ic| train_generator._current_date: datetime.datetime(2019, 5, 7, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 125
# ic| train_generator._current_date: datetime.datetime(2019, 5, 8, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 126
# ic| train_generator._current_date: datetime.datetime(2019, 5, 9, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 127
# ic| train_generator._current_date: datetime.datetime(2019, 5, 10, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 128
# ic| train_generator._current_date: datetime.datetime(2019, 5, 11, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 129
# ic| train_generator._current_date: datetime.datetime(2019, 5, 12, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 130
# ic| train_generator._current_date: datetime.datetime(2019, 5, 13, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 131
# ic| train_generator._current_date: datetime.datetime(2019, 5, 14, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 132
# ic| train_generator._current_date: datetime.datetime(2019, 5, 15, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 133
# ic| train_generator._current_date: datetime.datetime(2019, 5, 16, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 134
# ic| train_generator._current_date: datetime.datetime(2019, 5, 17, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 135
# ic| train_generator._current_date: datetime.datetime(2019, 5, 18, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 136
# ic| train_generator._current_date: datetime.datetime(2019, 5, 19, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 137
# ic| train_generator._current_date: datetime.datetime(2019, 5, 20, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 138
# ic| train_generator._current_date: datetime.datetime(2019, 5, 21, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 139
# ic| train_generator._current_date: datetime.datetime(2019, 5, 22, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 140
# ic| train_generator._current_date: datetime.datetime(2019, 5, 23, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 141
# ic| train_generator._current_date: datetime.datetime(2019, 5, 24, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 142
# ic| train_generator._current_date: datetime.datetime(2019, 5, 25, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 143
# ic| train_generator._current_date: datetime.datetime(2019, 5, 26, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 144
# ic| train_generator._current_date: datetime.datetime(2019, 5, 27, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 145
# ic| train_generator._current_date: datetime.datetime(2019, 5, 28, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 146
# ic| train_generator._current_date: datetime.datetime(2019, 5, 29, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 147
# ic| train_generator._current_date: datetime.datetime(2019, 5, 30, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 148
# ic| train_generator._current_date: datetime.datetime(2019, 5, 31, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 149
# ic| train_generator._current_date: datetime.datetime(2019, 6, 1, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 150
# ic| train_generator._current_date: datetime.datetime(2019, 6, 2, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 151
# ic| train_generator._current_date: datetime.datetime(2019, 6, 3, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 152
# ic| train_generator._current_date: datetime.datetime(2019, 6, 4, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 153
# ic| train_generator._current_date: datetime.datetime(2019, 6, 5, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 154
# ic| train_generator._current_date: datetime.datetime(2019, 6, 6, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 155
# ic| train_generator._current_date: datetime.datetime(2019, 6, 7, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 156
# ic| train_generator._current_date: datetime.datetime(2019, 6, 8, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 157
# ic| train_generator._current_date: datetime.datetime(2019, 6, 9, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 158
# ic| train_generator._current_date: datetime.datetime(2019, 6, 10, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 159
# ic| train_generator._current_date: datetime.datetime(2019, 6, 11, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 160
# ic| train_generator._current_date: datetime.datetime(2019, 6, 12, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 161
# ic| train_generator._current_date: datetime.datetime(2019, 6, 13, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 162
# ic| train_generator._current_date: datetime.datetime(2019, 6, 14, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 163
# ic| train_generator._current_date: datetime.datetime(2019, 6, 15, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 164
# ic| train_generator._current_date: datetime.datetime(2019, 6, 16, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 165
# ic| train_generator._current_date: datetime.datetime(2019, 6, 17, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 166
# ic| train_generator._current_date: datetime.datetime(2019, 6, 18, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 167
# ic| train_generator._current_date: datetime.datetime(2019, 6, 19, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 168
# ic| train_generator._current_date: datetime.datetime(2019, 6, 20, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 169
# ic| train_generator._current_date: datetime.datetime(2019, 6, 21, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 170
# ic| train_generator._current_date: datetime.datetime(2019, 6, 22, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 171
# ic| train_generator._current_date: datetime.datetime(2019, 6, 23, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 172
# ic| train_generator._current_date: datetime.datetime(2019, 6, 24, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 173
# ic| train_generator._current_date: datetime.datetime(2019, 6, 25, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 174
# ic| train_generator._current_date: datetime.datetime(2019, 6, 26, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 175
# ic| train_generator._current_date: datetime.datetime(2019, 6, 27, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 176
# ic| train_generator._current_date: datetime.datetime(2019, 6, 28, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 177
# ic| train_generator._current_date: datetime.datetime(2019, 6, 29, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 178
# ic| train_generator._current_date: datetime.datetime(2019, 6, 30, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 179
# ic| train_generator._current_date: datetime.datetime(2019, 7, 1, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 180
# ic| train_generator._current_date: datetime.datetime(2019, 7, 2, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 181
# ic| train_generator._current_date: datetime.datetime(2019, 7, 3, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 182
# ic| train_generator._current_date: datetime.datetime(2019, 7, 4, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 183
# ic| train_generator._current_date: datetime.datetime(2019, 7, 5, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 184
# ic| train_generator._current_date: datetime.datetime(2019, 7, 6, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 185
# ic| train_generator._current_date: datetime.datetime(2019, 7, 7, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 186
# ic| train_generator._current_date: datetime.datetime(2019, 7, 8, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 187
# ic| train_generator._current_date: datetime.datetime(2019, 7, 9, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 188
# ic| train_generator._current_date: datetime.datetime(2019, 7, 10, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 189
# ic| train_generator._current_date: datetime.datetime(2019, 7, 11, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 190
# ic| train_generator._current_date: datetime.datetime(2019, 7, 12, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 191
# ic| train_generator._current_date: datetime.datetime(2019, 7, 13, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 192
# ic| train_generator._current_date: datetime.datetime(2019, 7, 14, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 193
# ic| train_generator._current_date: datetime.datetime(2019, 7, 15, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 194
# ic| train_generator._current_date: datetime.datetime(2019, 7, 16, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 195
# ic| train_generator._current_date: datetime.datetime(2019, 7, 17, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 196
# ic| train_generator._current_date: datetime.datetime(2019, 7, 18, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 197
# ic| train_generator._current_date: datetime.datetime(2019, 7, 19, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 198
# ic| train_generator._current_date: datetime.datetime(2019, 7, 20, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 199
# ic| train_generator._current_date: datetime.datetime(2019, 7, 21, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 200
# ic| train_generator._current_date: datetime.datetime(2019, 7, 22, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 201
# ic| train_generator._current_date: datetime.datetime(2019, 7, 23, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 202
# ic| train_generator._current_date: datetime.datetime(2019, 7, 24, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 203
# ic| train_generator._current_date: datetime.datetime(2019, 7, 25, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 204
# ic| train_generator._current_date: datetime.datetime(2019, 7, 26, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 205
# ic| train_generator._current_date: datetime.datetime(2019, 7, 27, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 206
# ic| train_generator._current_date: datetime.datetime(2019, 7, 28, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 207
# ic| train_generator._current_date: datetime.datetime(2019, 7, 29, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 208
# ic| train_generator._current_date: datetime.datetime(2019, 7, 30, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 209
# ic| train_generator._current_date: datetime.datetime(2019, 7, 31, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 210
# ic| train_generator._current_date: datetime.datetime(2019, 8, 1, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 211
# ic| train_generator._current_date: datetime.datetime(2019, 8, 2, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 212
# ic| train_generator._current_date: datetime.datetime(2019, 8, 3, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 213
# ic| train_generator._current_date: datetime.datetime(2019, 8, 4, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 214
# ic| train_generator._current_date: datetime.datetime(2019, 8, 5, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 215
# ic| train_generator._current_date: datetime.datetime(2019, 8, 6, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 216
# ic| train_generator._current_date: datetime.datetime(2019, 8, 7, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 217
# ic| train_generator._current_date: datetime.datetime(2019, 8, 8, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 218
# ic| train_generator._current_date: datetime.datetime(2019, 8, 9, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 219
# ic| train_generator._current_date: datetime.datetime(2019, 8, 10, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 220
# ic| train_generator._current_date: datetime.datetime(2019, 8, 11, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 221
# ic| train_generator._current_date: datetime.datetime(2019, 8, 12, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 222
# ic| train_generator._current_date: datetime.datetime(2019, 8, 13, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 223
# ic| train_generator._current_date: datetime.datetime(2019, 8, 14, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 224
# ic| train_generator._current_date: datetime.datetime(2019, 8, 15, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 225
# ic| train_generator._current_date: datetime.datetime(2019, 8, 16, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 226
# ic| train_generator._current_date: datetime.datetime(2019, 8, 17, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 227
# ic| train_generator._current_date: datetime.datetime(2019, 8, 18, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 228
# ic| train_generator._current_date: datetime.datetime(2019, 8, 19, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 229
# ic| train_generator._current_date: datetime.datetime(2019, 8, 20, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 230
# ic| train_generator._current_date: datetime.datetime(2019, 8, 21, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 231
# ic| train_generator._current_date: datetime.datetime(2019, 8, 22, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 232
# ic| train_generator._current_date: datetime.datetime(2019, 8, 23, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 233
# ic| train_generator._current_date: datetime.datetime(2019, 8, 24, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 234
# ic| train_generator._current_date: datetime.datetime(2019, 8, 25, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 235
# ic| train_generator._current_date: datetime.datetime(2019, 8, 26, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 236
# ic| train_generator._current_date: datetime.datetime(2019, 8, 27, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 237
# ic| train_generator._current_date: datetime.datetime(2019, 8, 28, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 238
# ic| train_generator._current_date: datetime.datetime(2019, 8, 29, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 239
# ic| train_generator._current_date: datetime.datetime(2019, 8, 30, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 240
# ic| train_generator._current_date: datetime.datetime(2019, 8, 31, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 241
# ic| train_generator._current_date: datetime.datetime(2019, 9, 1, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 242
# ic| train_generator._current_date: datetime.datetime(2019, 9, 2, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 243
# ic| train_generator._current_date: datetime.datetime(2019, 9, 3, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 244
# ic| train_generator._current_date: datetime.datetime(2019, 9, 4, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 245
# ic| train_generator._current_date: datetime.datetime(2019, 9, 5, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 246
# ic| train_generator._current_date: datetime.datetime(2019, 9, 6, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 247
# ic| train_generator._current_date: datetime.datetime(2019, 9, 7, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 248
# ic| train_generator._current_date: datetime.datetime(2019, 9, 8, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 249
# ic| train_generator._current_date: datetime.datetime(2019, 9, 9, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 250
# ic| train_generator._current_date: datetime.datetime(2019, 9, 10, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 251
# ic| train_generator._current_date: datetime.datetime(2019, 9, 11, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 252
# ic| train_generator._current_date: datetime.datetime(2019, 9, 12, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 253
# ic| train_generator._current_date: datetime.datetime(2019, 9, 13, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 254
# ic| train_generator._current_date: datetime.datetime(2019, 9, 14, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 255
# ic| train_generator._current_date: datetime.datetime(2019, 9, 15, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 256
# ic| train_generator._current_date: datetime.datetime(2019, 9, 16, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 257
# ic| train_generator._current_date: datetime.datetime(2019, 9, 17, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 258
# ic| train_generator._current_date: datetime.datetime(2019, 9, 18, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 259
# ic| train_generator._current_date: datetime.datetime(2019, 9, 19, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 260
# ic| train_generator._current_date: datetime.datetime(2019, 9, 20, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 261
# ic| train_generator._current_date: datetime.datetime(2019, 9, 21, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 262
# ic| train_generator._current_date: datetime.datetime(2019, 9, 22, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 263
# ic| train_generator._current_date: datetime.datetime(2019, 9, 23, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 264
# ic| train_generator._current_date: datetime.datetime(2019, 9, 24, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 265
# ic| train_generator._current_date: datetime.datetime(2019, 9, 25, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 266
# ic| train_generator._current_date: datetime.datetime(2019, 9, 26, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 267
# ic| train_generator._current_date: datetime.datetime(2019, 9, 27, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 268
# ic| train_generator._current_date: datetime.datetime(2019, 9, 28, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 269
# ic| train_generator._current_date: datetime.datetime(2019, 9, 29, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 270
# ic| train_generator._current_date: datetime.datetime(2019, 9, 30, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 271
# ic| train_generator._current_date: datetime.datetime(2019, 10, 1, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 272
# ic| train_generator._current_date: datetime.datetime(2019, 10, 2, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 273
# ic| train_generator._current_date: datetime.datetime(2019, 10, 3, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 274
# ic| train_generator._current_date: datetime.datetime(2019, 10, 4, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 275
# ic| train_generator._current_date: datetime.datetime(2019, 10, 5, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 276
# ic| train_generator._current_date: datetime.datetime(2019, 10, 6, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 277
# ic| train_generator._current_date: datetime.datetime(2019, 10, 7, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 278
# ic| train_generator._current_date: datetime.datetime(2019, 10, 8, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 279
# ic| train_generator._current_date: datetime.datetime(2019, 10, 9, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 280
# ic| train_generator._current_date: datetime.datetime(2019, 10, 10, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 281
# ic| train_generator._current_date: datetime.datetime(2019, 10, 11, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 282
# ic| train_generator._current_date: datetime.datetime(2019, 10, 12, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 283
# ic| train_generator._current_date: datetime.datetime(2019, 10, 13, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 284
# ic| train_generator._current_date: datetime.datetime(2019, 10, 14, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 285
# ic| train_generator._current_date: datetime.datetime(2019, 10, 15, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 286
# ic| train_generator._current_date: datetime.datetime(2019, 10, 16, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 287
# ic| train_generator._current_date: datetime.datetime(2019, 10, 17, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 288
# ic| train_generator._current_date: datetime.datetime(2019, 10, 18, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 289
# ic| train_generator._current_date: datetime.datetime(2019, 10, 19, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 290
# ic| train_generator._current_date: datetime.datetime(2019, 10, 20, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 291
# ic| train_generator._current_date: datetime.datetime(2019, 10, 21, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 292
# ic| train_generator._current_date: datetime.datetime(2019, 10, 22, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 293
# ic| train_generator._current_date: datetime.datetime(2019, 10, 23, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 294
# ic| train_generator._current_date: datetime.datetime(2019, 10, 24, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 295
# ic| train_generator._current_date: datetime.datetime(2019, 10, 25, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 296
# ic| train_generator._current_date: datetime.datetime(2019, 10, 26, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 297
# ic| train_generator._current_date: datetime.datetime(2019, 10, 27, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 298
# ic| train_generator._current_date: datetime.datetime(2019, 10, 28, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 299
# ic| train_generator._current_date: datetime.datetime(2019, 10, 29, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 300
# ic| train_generator._current_date: datetime.datetime(2019, 10, 30, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 301
# ic| train_generator._current_date: datetime.datetime(2019, 10, 31, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 302
# ic| train_generator._current_date: datetime.datetime(2019, 11, 1, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 303
# ic| train_generator._current_date: datetime.datetime(2019, 11, 2, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 304
# ic| train_generator._current_date: datetime.datetime(2019, 11, 3, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 305
# ic| train_generator._current_date: datetime.datetime(2019, 11, 4, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 306
# ic| train_generator._current_date: datetime.datetime(2019, 11, 5, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 307
# ic| train_generator._current_date: datetime.datetime(2019, 11, 6, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 308
# ic| train_generator._current_date: datetime.datetime(2019, 11, 7, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 309
# ic| train_generator._current_date: datetime.datetime(2019, 11, 8, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 310
# ic| train_generator._current_date: datetime.datetime(2019, 11, 9, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 311
# ic| train_generator._current_date: datetime.datetime(2019, 11, 10, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 312
# ic| train_generator._current_date: datetime.datetime(2019, 11, 11, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 313
# ic| train_generator._current_date: datetime.datetime(2019, 11, 12, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 314
# ic| train_generator._current_date: datetime.datetime(2019, 11, 13, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 315
# ic| train_generator._current_date: datetime.datetime(2019, 11, 14, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 316
# ic| train_generator._current_date: datetime.datetime(2019, 11, 15, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 317
# ic| train_generator._current_date: datetime.datetime(2019, 11, 16, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 318
# ic| train_generator._current_date: datetime.datetime(2019, 11, 17, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 319
# ic| train_generator._current_date: datetime.datetime(2019, 11, 18, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 320
# ic| train_generator._current_date: datetime.datetime(2019, 11, 19, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| iter: 321
# ic| train_generator._current_date: datetime.datetime(2019, 1, 1, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)

# %%
steps_per_epoch = 0
for eval_sim in train_generator._sim_memory:
    steps_per_epoch += len(eval_sim.event_queue.queue)

ic(steps_per_epoch)
# Out:
# ic| steps_per_epoch: 59342
# 59342

# %%
eval_generator.seed = 8734956
_ = eval_generator.reset()

iter = 0

while eval_generator._current_date != eval_generator.start_date:
    _ = eval_generator.next()

    ic(iter)
    ic(eval_generator._current_date)
    iter += 1
    
steps_per_epoch_eval = 0
for eval_sim in eval_generator._sim_memory:
    steps_per_epoch_eval += len(eval_sim.event_queue.queue)

ic(steps_per_epoch_eval)
# Out:
# ic| iter: 0
# ic| eval_generator._current_date: datetime.datetime(2019, 11, 20, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| steps_per_epoch_eval: 5149
# 5149

# %%
train_config = {"observation_objects": observation_objects, "action_object": zero_centered_single_charging_schedule_normalized(),
                "reward_objects": reward_objects,
                "simgenerator": train_generator,
                "meet_constraints": True}

eval_config = train_config | {'simgenerator': eval_generator}
# validation_config = train_config | {'simgenerator': validation_generator}

# %%
from acnportal.algorithms import UncontrolledCharging, SortedSchedulingAlgo, last_come_first_served, \
    first_come_first_served

model = ACNSchedule(SortedSchedulingAlgo(first_come_first_served))

# %%
from tqdm import tqdm
import pandas as pd

def create_df(model, name: str, env, steps_per_epoch):
    df_list = []
    
    done = False
    old_obs, _ = env.reset()

    for _ in tqdm(range(steps_per_epoch)):

        iface = env.unwrapped.interface
        action = model.get_action(old_obs, iface)

        new_obs, rew, terminated, truncated, _ = env.step(
            action)
        done = terminated or truncated

        df_list.append([old_obs.tolist(), action.tolist(), rew, done])

        if done:
            new_obs, _ = env.reset()
            done = False
            
        old_obs = new_obs
        
    df = pd.DataFrame(df_list, columns=['observation', 'action', 'reward', 'done'])
    df.to_parquet(f'{name}.parquet.gzip', compression='gzip')

# %%
from src.cleanRL.environment import make_env

create_df(model, "FCFS_gen_triple_46_weeks_training", make_env(train_config, 0.99, 0)(), steps_per_epoch)
create_df(model, "FCFS_gen_triple_46_weeks_validation", make_env(eval_config, 0.99, 0)(), steps_per_epoch_eval)
# Out:
#   0%|          | 231/59342 [00:21<1:01:15, 16.08it/s]/home/guest/tsturm/acn-experiments/.conda/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /home/guest/tsturm/acn-experiments/.conda/lib/python3.9/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 59342/59342 [1:30:11<00:00, 10.97it/s]
# 100%|██████████| 5149/5149 [08:03<00:00, 10.65it/s]
