# %%
from datetime import datetime, timedelta
from tqdm import tqdm
from acn_experiments.run_simulation import run_simulations, metrics

# %%
from gymportal.data.ev_generators import get_standard_generator, RealWorldGenerator
from acnportal.acnsim import Linear2StageBattery
from gymportal.data.battery_generators import CustomizableBatteryGenerator
from gymportal.sim import get_charging_network, Recomputer, EvaluationSimulator, SimGenerator
from icecream import ic

import pytz
timezone = pytz.timezone("America/Los_Angeles")

# charging_network = get_charging_network('simple_acn', basic_evse=True, voltage=208,
                                        # network_kwargs={
                                            # 'station_ids': ['CA-504', 'CA-503', 'CA-502', 'CA-501'],
                                             #'station_ids': ['CA-501'],
# "aggregate_cap": 32 * 208 / 1000})

charging_network = get_charging_network('caltech', basic_evse=True, voltage=208,
                                        network_kwargs={"transformer_cap": 40 * 32 * 208 / 1000})

battery_generator = CustomizableBatteryGenerator(voltage=208,
                                                 period=1,
                                                 battery_types=[
                                                     Linear2StageBattery],
                                                 max_power_function='normal')

ev_generator = RealWorldGenerator(battery_generator=battery_generator, site='caltech', period=1)
# ev_generator = get_standard_generator('caltech', battery_generator, seed=42)

train_generator = SimGenerator(
    charging_network=charging_network,
    simulation_days=7,
    n_intervals=46,
    start_date=timezone.localize(datetime(2019, 1, 1)),
    ev_generator=ev_generator,
    recomputer=Recomputer(recompute_interval=10, sparse=True),
    sim_class=EvaluationSimulator,
)

ic(train_generator.end_date + timedelta(days=1))

eval_generator = SimGenerator(
    charging_network=charging_network,
    simulation_days=7,
    n_intervals=1,
    start_date=train_generator.end_date + timedelta(days=1),
    ev_generator=ev_generator,
    recomputer=Recomputer(recompute_interval=10, sparse=True),
    sim_class=EvaluationSimulator,
)

ic(eval_generator.end_date + timedelta(days=1))

validation_generator = SimGenerator(
    charging_network=charging_network,
    simulation_days=14,
    n_intervals=1,
    start_date=eval_generator.end_date + timedelta(days=1),
    ev_generator=ev_generator,
    recomputer=Recomputer(recompute_interval=10, sparse=True),
    sim_class=EvaluationSimulator,
)

ic(validation_generator.end_date + timedelta(days=1))
pass
# Out:
# ic| train_generator.end_date + timedelta(days=1): datetime.datetime(2019, 11, 20, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| eval_generator.end_date + timedelta(days=1): datetime.datetime(2019, 11, 28, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)
# ic| validation_generator.end_date + timedelta(days=1): datetime.datetime(2019, 12, 13, 0, 0, tzinfo=<DstTzInfo 'America/Los_Angeles' PST-1 day, 16:00:00 STD>)

# %%
from gymportal.environment import *
from src.extra import unplug_penalty, ranking_schedule_plus


observation_objects = [
    charging_rates_observation_normalized(),
    percentage_of_magnitude_observation(),
    diff_pilots_charging_rates_observation_normalized(),
    cyclical_minute_observation(),
    cyclical_day_observation(),
    cyclical_month_observation(),
    cyclical_minute_observation_stay(),
    energy_delivered_observation_normalized(),
    num_active_stations_observation_normalized(),
    pilot_signals_observation_normalized(),
    cyclical_minute_observation_arrival(),
    cyclical_day_observation_arrival(),
    cyclical_month_observation_arrival(),
]

reward_objects = [
    # current_constraint_violation(),
    # soft_charging_reward(),
    constraint_charging_reward(),
    unplug_penalty(),
    # pilot_charging_rate_difference_penalty(),
]

# %%
train_config = {"observation_objects": observation_objects, "action_object": ranking_schedule_plus(),
                "reward_objects": reward_objects,
                "simgenerator": train_generator,
                "meet_constraints": False}

eval_config = train_config | {'simgenerator': eval_generator}
validation_config = train_config | {'simgenerator': validation_generator}

# %%
from acn_experiments.utils import FlattenSimEnv
from src.ppo_custom.ppo_model import PPO

env = FlattenSimEnv(config=train_config)
algo = PPO(env)

# %%
from gymportal.evaluation import ACNSchedule, RllibSchedule
from acnportal.algorithms import UncontrolledCharging, SortedSchedulingAlgo, last_come_first_served, \
    first_come_first_served
from acn_experiments.utils import CustomSchedule


models = {
    "PPO": CustomSchedule(algo),
    "FCFS": ACNSchedule(SortedSchedulingAlgo(first_come_first_served)),
    "LCFS": ACNSchedule(SortedSchedulingAlgo(last_come_first_served)),
    "Uncontrolled": ACNSchedule(UncontrolledCharging()),
}

models
# Out:
# {'PPO': <acn_experiments.utils.CustomSchedule at 0x7fcf1f1e0b20>,
#  'FCFS': <gymportal.evaluation.can_schedule.ACNSchedule at 0x7fcf1f1e0fd0>,
#  'LCFS': <gymportal.evaluation.can_schedule.ACNSchedule at 0x7fcf1f1e0610>,
#  'Uncontrolled': <gymportal.evaluation.can_schedule.ACNSchedule at 0x7fcf1f1e0100>}

# %%
df_before = run_simulations(models, metrics=metrics, config=eval_config, seed=42)
# Out:
# Models:   0%|          | 0/4 [01:22<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df_before = run_simulations(models, metrics=metrics, config=eval_config, seed=42)
#
# File ~/git/acn-experiments/.conda/lib/python3.9/site-packages/acn_experiments/run_simulation.py:36, in run_simulations(models, metrics, config, change_action_object_automatically, seed)
#      33     else:
#      34         env_type = SingleAgentSimEnv
# ---> 36     sims[algo_name] = evaluate_model(scheduler, env_type=env_type, env_config=configs[algo_name],
#      37                                      seed=seed)
#      39 results = {metric_name: [m(s) for s in sims.values()]
#      40            for metric_name, m in metrics.items()}
#      41 results_df = pd.DataFrame.from_dict(results)
#
# File ~/git/acn-experiments/.conda/lib/python3.9/site-packages/gymportal/evaluation/evaluation.py:40, in evaluate_model(model, env_type, env_config, seed)
#      37 while not done:
#      38     action = model.get_action(observation, eval_env.interface)
# ---> 40     observation, reward, terminated, truncated, info = eval_env.step(action)
#      42     if isinstance(eval_env, MultiAgentEnv):
#      43         done = terminated['__all__'] or truncated['__all__']
#
# File ~/git/acn-experiments/.conda/lib/python3.9/site-packages/gymnasium/core.py:469, in ObservationWrapper.step(self, action)
#     465 def step(
#     466     self, action: ActType
#     467 ) -> tuple[WrapperObsType, SupportsFloat, bool, bool, dict[str, Any]]:
#     468     """Modifies the :attr:`env` after calling :meth:`step` using :meth:`self.observation` on the returned observations."""
# --> 469     observation, reward, terminated, truncated, info = self.env.step(action)
#     470     return self.observation(observation), reward, terminated, truncated, info
#
# File ~/git/acn-experiments/.conda/lib/python3.9/site-packages/gymportal/environment/environment.py:79, in SingleAgentSimEnv.step(self, action)
#      76 def step(
#      77         self, action: np.ndarray
#      78 ) -> Tuple[ObsType, float, bool, bool, Dict[str, Any]]:
# ---> 79     return CustomSimInterface.step(self, action)
#
# File ~/git/acn-experiments/.conda/lib/python3.9/site-packages/gymportal/environment/interfaces/custom_sim_interface.py:171, in CustomSimInterface.step(self, action)
#     170 def step(self, action):
# --> 171     out = super().step(action)
#     172     self._attempt_store_rewards()
#     173     return out
#
# File ~/git/acn-experiments/.conda/lib/python3.9/site-packages/gymportal/environment/interfaces/base_sim_interface.py:191, in BaseSimInterface.step(self, action)
#     189 def step(self, action):
#     190     self.action = action
# --> 191     self.schedule = self.action_to_schedule()
#     193     if self.meet_constraints:
#     194         self.fix_schedule()
#
# File ~/git/acn-experiments/.conda/lib/python3.9/site-packages/gymportal/environment/interfaces/custom_sim_interface.py:155, in CustomSimInterface.action_to_schedule(self)
#     147 def action_to_schedule(self) -> Dict[str, List[float]]:
#     148     """ Convert an agent action to a schedule to be input to the
#     149     simulator.
#     150
#    (...)
#     153             station ids to a schedule of pilot signals.
#     154     """
# --> 155     return self.action_object.get_schedule(self.interface, self.action)
#
# File ~/git/acn-experiments/.conda/lib/python3.9/site-packages/gymportal/environment/actions.py:128, in SimAction.get_schedule(self, interface, action)
#     121 if isinstance(action, np.ndarray) and len(action.shape) > 1:
#     122     raise TypeError(
#     123         f"Single schedule action type only accepts schedules "
#     124         f"of length <= 1 in a 1-D numpy array. Got shape = "
#     125         f"{len(action.shape)}."
#     126     )
# --> 128 return self._to_schedule(interface, action)
#
# File ~/git/acn-experiments/.conda/lib/python3.9/site-packages/src/extra.py:158, in ranking_schedule_plus.<locals>.to_schedule(iface, action)
#     155 scheduler = SortedSchedulingAlgo(sort_fn=sort_fn)
#     157 scheduler.register_interface(iface)
# --> 158 sessions = list(np.array(iface.active_sessions())[action > 0])
#     160 action_out = {station: [0] for station in iface.station_ids} | scheduler.schedule(sessions)
#     162 return action_out
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 1 but corresponding boolean dimension is 4

# %%
df_before.to_csv("before.csv")
ax = df_before.plot.bar()
fig = ax.get_figure()
fig.savefig("before.png", dpi=600)

# %%
import wandb
wandb.init(project="ppo_test", name="ranking+")
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: tsturm (tsturm-university-kassel). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.6
# Run data is saved locally in <code>/home/y/git/acn-experiments/custom/wandb/run-20241107_014518-tsh4t4ip</code>
# Syncing run <strong><a href='https://wandb.ai/tsturm-university-kassel/ppo_test/runs/tsh4t4ip' target="_blank">xxx</a></strong> to <a href='https://wandb.ai/tsturm-university-kassel/ppo_test' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/tsturm-university-kassel/ppo_test' target="_blank">https://wandb.ai/tsturm-university-kassel/ppo_test</a>
#  View run at <a href='https://wandb.ai/tsturm-university-kassel/ppo_test/runs/tsh4t4ip' target="_blank">https://wandb.ai/tsturm-university-kassel/ppo_test/runs/tsh4t4ip</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/tsturm-university-kassel/ppo_test/runs/tsh4t4ip?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
from pytorch_lightning import Trainer
from pytorch_lightning.loggers import WandbLogger

wandb_logger = WandbLogger(log_model="all")

# model = PPO(env)
trainer = Trainer(max_epochs=3, logger=wandb_logger, accelerator="cpu", callbacks=[])
res = trainer.fit(algo)
res
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# /home/y/git/acn-experiments/.conda/lib/python3.9/site-packages/pytorch_lightning/utilities/parsing.py:44: Attribute 'env' removed from hparams because it cannot be pickled. You can suppress this warning by setting `self.save_hyperparameters(ignore=['env'])`.
# /home/y/git/acn-experiments/.conda/lib/python3.9/site-packages/pytorch_lightning/loggers/wandb.py:396: There is a wandb run already in progress and newly created instances of `WandbLogger` will reuse this run. If this is not desired, call `wandb.finish()` before instantiating `WandbLogger`.
#
#   | Name   | Type           | Params | Mode
# --------------------------------------------------
# 0 | critic | Sequential     | 23.9 K | train
# 1 | actor  | ActorContinous | 24.3 K | train
# --------------------------------------------------
# 48.3 K    Trainable params
# 0         Non-trainable params
# 48.3 K    Total params
# 0.193     Total estimated model params size (MB)
# 13        Modules in train mode
# 0         Modules in eval mode
# /home/y/git/acn-experiments/.conda/lib/python3.9/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:424: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# Training: |          | 0/? [00:00<?, ?it/s]
# `Trainer.fit` stopped: `max_epochs=3` reached.

# %%
wandb.finish()
# Out:
# VBox(children=(Label(value='0.008 MB of 0.008 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>avg_ep_len</td><td>▁█▇</td></tr><tr><td>avg_ep_reward</td><td>▁█▆</td></tr><tr><td>avg_reward</td><td>▁█▇</td></tr><tr><td>epoch</td><td>▁▅█</td></tr><tr><td>trainer/global_step</td><td>▁▅█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>avg_ep_len</td><td>221.59723</td></tr><tr><td>avg_ep_reward</td><td>45.41837</td></tr><tr><td>avg_reward</td><td>0.20753</td></tr><tr><td>epoch</td><td>2</td></tr><tr><td>trainer/global_step</td><td>11</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">xxx</strong> at: <a href='https://wandb.ai/tsturm-university-kassel/ppo_test/runs/tsh4t4ip' target="_blank">https://wandb.ai/tsturm-university-kassel/ppo_test/runs/tsh4t4ip</a><br/> View project at: <a href='https://wandb.ai/tsturm-university-kassel/ppo_test' target="_blank">https://wandb.ai/tsturm-university-kassel/ppo_test</a><br/>Synced 4 W&B file(s), 0 media file(s), 3 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241107_014518-tsh4t4ip/logs</code>

# %%
from datetime import datetime

eval_generator = SimGenerator(
    charging_network=charging_network,
    simulation_days=1,
    n_intervals=1,
    start_date=timezone.localize(datetime(2019, 9, 23)),
    ev_generator=ev_generator,
    recomputer=Recomputer(recompute_interval=10, sparse=True),
    sim_class=EvaluationSimulator,
)

evaluation_config = train_config | {"simgenerator": eval_generator}

# %%
from gymportal.plotting.plotting import plot_sim_evaluation
from gymportal.evaluation import evaluate_model

eval_sim = evaluate_model(CustomSchedule(
    algo), env_type=FlattenSimEnv, env_config=evaluation_config)


_ = plot_sim_evaluation(eval_sim)#.savefig("evaluation.png", dpi=300)

# %%
from gymportal.plotting.plotting import plot_sim_evaluation

_ = plot_sim_evaluation(eval_sim)

# %%
df_after = run_simulations(models, metrics=metrics, config=eval_config, seed=42)
# Out:
# Models:  25%|██▌       | 1/4 [01:22<04:08, 82.71s/it]/home/y/git/acn-experiments/.conda/lib/python3.9/site-packages/gymnasium/spaces/box.py:130: UserWarning: WARN: Box bound precision lowered by casting to float32
#   gym.logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Models:  50%|█████     | 2/4 [02:43<02:43, 81.64s/it]/home/y/git/acn-experiments/.conda/lib/python3.9/site-packages/gymnasium/spaces/box.py:130: UserWarning: WARN: Box bound precision lowered by casting to float32
#   gym.logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Models:  75%|███████▌  | 3/4 [04:16<01:26, 86.69s/it]/home/y/git/acn-experiments/.conda/lib/python3.9/site-packages/gymnasium/spaces/box.py:130: UserWarning: WARN: Box bound precision lowered by casting to float32
#   gym.logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# Models: 100%|██████████| 4/4 [05:35<00:00, 83.94s/it]

# %%
df_after.to_csv("after.csv")
ax = df_after.plot.bar()
fig = ax.get_figure()
fig.savefig("after.png", dpi=600)

# %% [markdown]
# ## Before training:

# %%
df_before
# Out:
#               SoC >= 90%  mean SoC  median SoC  prop feasible steps  \
# Algorithms
# PPO             1.000000  0.971334    0.977410             1.000000
# FCFS            1.000000  0.979617    0.969948             1.000000
# LCFS            0.666667  0.909603    0.987236             1.000000
# Uncontrolled    1.000000  0.985379    0.987236             0.996682
#
#               prop feasible charge
# Algorithms
# PPO                       1.000000
# FCFS                      1.000000
# LCFS                      1.000000
# Uncontrolled              0.997879

# %% [markdown]
# ## After training:

# %%
df_after
# Out:
#               SoC >= 90%  mean SoC  median SoC  prop feasible steps  \
# Algorithms
# PPO             0.666667  0.950982    0.983019             1.000000
# FCFS            1.000000  0.979617    0.969948             1.000000
# LCFS            0.666667  0.909603    0.987236             1.000000
# Uncontrolled    1.000000  0.985379    0.987236             0.996682
#
#               prop feasible charge
# Algorithms
# PPO                       1.000000
# FCFS                      1.000000
# LCFS                      1.000000
# Uncontrolled              0.997879
